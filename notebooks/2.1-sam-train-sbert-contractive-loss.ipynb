# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, LoggingHandler, losses
from torch.utils.data import DataLoader, RandomSampler
from torch.optim import AdamW
from tqdm import tqdm

import sys
sys.path.append('../')

# %%
from src.utils.data_constractor import CompanyDatasetSentBert

# %% [markdown]
# ### Learning

# %%
PATH_DATA = '../data/preprocess_train.csv'
BATCH_SIZE = 32
MODEL_INIT = 'all-MiniLM-L6-v2'
DEVICE = 'cuda:1'
EPOCHS = 3
LR = 2e-5

# %%
train_dataset = CompanyDatasetSentBert(PATH_DATA)
val_dataset = CompanyDatasetSentBert(PATH_DATA, train=False)
len(train_dataset), len(val_dataset)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 472928/472928 [00:08<00:00, 53674.44it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 24891/24891 [00:00<00:00, 64114.59it/s]
# (472928, 24891)

# %%
train_dataset.samples[0], val_dataset.samples[0]
# Out:
# (<sentence_transformers.readers.InputExample.InputExample at 0x7f4acd44fd60>,
#  <sentence_transformers.readers.InputExample.InputExample at 0x7f4ac021efa0>)

# %%
trainDataLoader = DataLoader(
    train_dataset,
    sampler=RandomSampler(train_dataset),
    batch_size=32
)

# %%
model = SentenceTransformer('all-MiniLM-L6-v2', device=DEVICE)
model.max_seq_length = 60
trainLoss = losses.ContrastiveLoss(model=model)
model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 60, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# )

# %%
warmup_steps = int(len(trainDataLoader) * EPOCHS * 0.1)

model.fit(
    train_objectives=[(trainDataLoader, train_loss)], 
    epochs=EPOCHS,
    warmup_steps=warmup_steps,
    output_path='../weights/sbert',
    optimizer_params={'lr': LR},
    save_best_model=True,
    show_progress_bar=True
)
# Out:
# Epoch:   0%|          | 0/3 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/14779 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/14779 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/14779 [00:00<?, ?it/s]

# %% [markdown]
# ### Eval

# %%
from sentence_transformers import SentenceTransformer, util
from sklearn.metrics import f1_score, confusion_matrix, classification_report, precision_recall_curve
import numpy as np
from tqdm import tqdm

import sys
sys.path.append('../')

# %%
from src.utils.data_constractor import CompanyDatasetSentBert

# %%
DEVICE = 'cuda:2'
PATH_DATA = '../data/preprocess_train.csv'

# %%
model = SentenceTransformer('../weights/sbert', device=DEVICE)
model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 60, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# )

# %%
val_dataset = CompanyDatasetSentBert(PATH_DATA, train=False)
val_dataset.samples
# Out:
#                                                    name_1  \
# 304006  divekar wallstabe &schneider precision seals p.l.
# 271233                          first world asian trading
# 185141                                  dipanjali sharees
# 396834                                           qsr inc.
# 151609                           aa synthetic fibers ltd.
# ...                                                   ...
# 186356          h & v advanced materials india pvt., ltd.
# 297374                                focha trading l l c
# 424530                                    psa corporation
# 317898                     ncm hersbit chemical co., ltd.
# 251714                           the dow chemical company
#
#                                       name_2  is_duplicate
# 304006                         e&a scheer bv             0
# 271233                              stp ltd.             0
# 185141                     i b international             0
# 396834      onguard fire protection services             0
# 151609  indian synthetic rubber private ltd.             0
# ...                                      ...           ...
# 186356                    welspun india ltd.             0
# 297374             corp. tadzai s.a. de c.v.             0
# 424530                 shams alzohor trading             0
# 317898                 lidorr chemicals ltd.             0
# 251714                      ennis-flint inc.             0
#
# [24891 rows x 3 columns]

# %%
val_dataset.samples['is_duplicate'].value_counts()
# Out:
# 0    24708
# 1      183
# Name: is_duplicate, dtype: int64

# %%
cosine_score = list()
for idx in tqdm(range(len(val_dataset.samples))):
    curr_list_cmp = val_dataset.samples[['name_1', 'name_2']].iloc[idx].tolist()
    embeddings = model.encode(curr_list_cmp, convert_to_tensor=True, device=DEVICE)
    cosine_score.append(util.cos_sim(embeddings[0], embeddings[1])[0][0].item())

val_dataset.samples['cosine_score'] = cosine_score

# %%
val_dataset.samples.head()
# Out:
#                                                    name_1  \
# 304006  divekar wallstabe &schneider precision seals p.l.
# 271233                          first world asian trading
# 185141                                  dipanjali sharees
# 396834                                           qsr inc.
# 151609                           aa synthetic fibers ltd.
#
#                                       name_2  is_duplicate  cosine_score
# 304006                         e&a scheer bv             0      0.162562
# 271233                              stp ltd.             0      0.101912
# 185141                     i b international             0      0.063827
# 396834      onguard fire protection services             0      0.139751
# 151609  indian synthetic rubber private ltd.             0      0.547664

# %%
label_zero = val_dataset.samples[val_dataset.samples['is_duplicate'] == 0]['cosine_score']
label_one = val_dataset.samples[val_dataset.samples['is_duplicate'] == 1]['cosine_score']

# %%
label_one.describe()
# Out:
# count    183.000000
# mean       0.634709
# std        0.176863
# min        0.186636
# 25%        0.523047
# 50%        0.642733
# 75%        0.744277
# max        1.000000
# Name: cosine_score, dtype: float64

# %%
label_zero.describe()
# Out:
# count    24708.000000
# mean         0.338060
# std          0.170048
# min         -0.093053
# 25%          0.203308
# 50%          0.328723
# 75%          0.459828
# max          0.977624
# Name: cosine_score, dtype: float64

# %%
val_dataset.samples[
    (val_dataset.samples['cosine_score'] > 0.9) & (val_dataset.samples['is_duplicate'] == 0)
]
# Out:
#                                                  name_1  \
# 65404   qingdao xinye international logistics co., ltd.
# 389708                            arp materials inc.200
# 219607                    al estagamah flexiflo factory
# 477899                           ana de mexico sa de cv
#
#                                    name_2  is_duplicate  cosine_score
# 65404   qingdao yida world logistics ltd.             0      0.902590
# 389708                 arp materials inc.             0      0.951161
# 219607       al estagmah flexiflo factory             0      0.977624
# 477899                s i de mexico sa cv             0      0.911499

# %%
val_dataset.samples[
    (val_dataset.samples['cosine_score'] > 0.8) & (val_dataset.samples['is_duplicate'] == 0)
]
# Out:
#                                                    name_1  \
# 85000                   jianda rubber (tianjin) co., ltd.
# 196906                             htp de mexico sa de cv
# 422657           dongguan hongfu shoes products co., ltd.
# 54954                       pelzer de mexico s.a. de c.v.
# 347526   qingdao han yu international logistics co., ltd.
# ...                                                   ...
# 181219             qingdao qianhetong logistics co., ltd.
# 14166             dongguan yixin shoes material co., ltd.
# 330733          zhongshan taiyang imp. & exp. . co., ltd.
# 315054  crown yun precision plastic hardware (shenzhen...
# 371453  guangzhou city.,zhengxin rubber plastic co., ltd.
#
#                                                 name_2  is_duplicate  \
# 85000               donghai rubber (tianjin) co., ltd.             0
# 196906                          ksb de mexico sa de cv             0
# 422657                 dongguan dingli shoes co., ltd.             0
# 54954                    sovere de mexico s.a. de c.v.             0
# 347526            qingdao chunming logistics co., ltd.             0
# ...                                                ...           ...
# 181219      shenzhen taijihengtong logistics co., ltd.             0
# 14166                 dongguan xinglai shoes co., ltd.             0
# 330733      tiantai huang teng imp. & exp. . co., ltd.             0
# 315054  yun lee precision plastic (shenzhen) co., ltd.             0
# 371453              guangzhou zengwei rubber co., ltd.             0
#
#         cosine_score
# 85000       0.857441
# 196906      0.827980
# 422657      0.843981
# 54954       0.810501
# 347526      0.832978
# ...              ...
# 181219      0.803177
# 14166       0.889610
# 330733      0.810003
# 315054      0.884402
# 371453      0.837947
#
# [100 rows x 4 columns]

# %%
val_dataset.samples[
    (val_dataset.samples['cosine_score'] < 0.5) & (val_dataset.samples['is_duplicate'] == 1)
]
# Out:
#                                                    name_1  \
# 433081        bridgestone neumaticos de monterreysa de cv
# 139877                                          sodeks ag
# 65782                                       total rumunia
# 355132                                  jsr bst elastomer
# 246590                flex?computing?(suzhou) ?co.,? ltd.
# 441499            bridgestone firestone de argentina saic
# 253255                            soprema polska sp z o o
# 21770                                           iko sales
# 428898    bridgestone do brasil industria & comercio ltda
# 401204                          bridgestone americas tire
# 224729                 bridgestone de mexico s.a. de c.v.
# 116773            vetus & maxwell marine india pvt., ltd.
# 376422  sociedade michelin de participacoes indust e c...
# 416879                          bridgestone hosepower llc
# 9820             bridgestone firestone de mexico sa de cv
# 221487         brenntag chile comercial e industrial ltda
# 159522                          bridgestone neumaticos de
# 153744                    contitech antriebssysteme gmb h
# 191776                                         k flex usa
# 395181                          bridgestone neumaticos de
# 27757                                             basf sa
# 191901                     total bitumen deutschland gmbh
# 218317   bridgestone do brasil industria e comenrcio ltda
# 120943                    bridgestone firestone do brasil
# 266900                          bridgestone neumaticos de
# 412201                                             makyol
# 162579                                   bridgestone tire
# 235010                       bridgestone india automotive
# 46664                       warren plant bato bridgestone
# 78272                                             basf sa
# 467352                                     total bitumen*
# 214422                                    bridgestone ncr
# 445921                                 contitech chile sa
# 130618           bridgestone de costa rica sociedad anoni
# 117660                                 total bitumen gmbh
# 116181                           biesterfeld plastic gmbh
# 189500                                   bridgestone tire
# 290539    jowat se"/cherez terminal a.c."pol-sad",pol'sha
# 15240                                        goter s.r.l.
# 90645       a.p.i. applicazioni plastiche industriali spa
# 443673                     ktn underwood arlanxeo usa llc
# 455725                                         k flex usa
# 199925                      interteks vorld resursis ink.
# 397194                       bridgestone india pvt., ltd.
#
#                                                   name_2  is_duplicate  \
# 433081                    bridgestone de costa rica s.a.             1
# 139877                                          sodex ag             1
# 65782                                 total romania s.a.             1
# 355132                                              ltd.             1
# 246590                                          flex sol             1
# 441499                     pt bridgestone tire indonesia             1
# 253255                                    soprema iberia             1
# 21770                                iko eu /all plants*             1
# 428898                bridgestone de mexico s.a. de c.v.             1
# 401204          bridgestone de costa rica sociedad anoni             1
# 224729              bridgestone (huizhou) tire co., ltd.             1
# 116773                                           maxwell             1
# 376422                                    michelin group             1
# 416879   bridgestone do brasil industria e comercio ltda             1
# 9820                bridgestone (tianjin) tire co., ltd.             1
# 221487                             brenntag ecuador s.a.             1
# 159522                bridgestone de mexico s.a. de c.v.             1
# 153744                       contitech mexicana sa de cv             1
# 191776                               nitro flex x s.a.c.             1
# 395181                        thai bridgestone co., ltd.             1
# 27757                       basf quimica colombiana s.a.             1
# 191901                       total france (arnay le duc)             1
# 218317                    bridgestone de costa rica s.a.             1
# 120943                         bridgestone neumaticos de             1
# 266900          bridgestone firestone de mexico sa de cv             1
# 412201        makyol insaat sanayi turizm ve ticaret a s             1
# 162579                   bridgestone firestone do brasil             1
# 235010                bridgestone de mexico s.a. de c.v.             1
# 46664                                   bridgestone tire             1
# 78272                basf de costa rica sociedad anonima             1
# 467352                           total polska sp. z o.o.             1
# 214422  bridgestone do brasil industria e comenrcio ltda             1
# 445921                   contitech antriebssysteme gmb h             1
# 130618                         bridgestone neumaticos de             1
# 117660                      total ceska republika s.r.o.             1
# 116181                             ooo "bisterfel'd rus"             1
# 189500       bridgestone neumaticos de monterreysa de cv             1
# 290539                                       ooo"ĭovat"             1
# 15240                goter thermoplastic compounds s.p.a             1
# 90645                                        trinseo api             1
# 443673                                arlanxeo brasil sa             1
# 455725                             l'isolante k-flex spa             1
# 199925                     intertex world resources ltd.             1
# 397194   bridgestone do brasil industria e comercio ltda             1
#
#         cosine_score
# 433081      0.463480
# 139877      0.454534
# 65782       0.477875
# 355132      0.186636
# 246590      0.482999
# 441499      0.408333
# 253255      0.386867
# 21770       0.433298
# 428898      0.404132
# 401204      0.386836
# 224729      0.397560
# 116773      0.410662
# 376422      0.400494
# 416879      0.381644
# 9820        0.489367
# 221487      0.438705
# 159522      0.455153
# 153744      0.284138
# 191776      0.490492
# 395181      0.487919
# 27757       0.445070
# 191901      0.376283
# 218317      0.393052
# 120943      0.477232
# 266900      0.496390
# 412201      0.457748
# 162579      0.438912
# 235010      0.415114
# 46664       0.455147
# 78272       0.481123
# 467352      0.270193
# 214422      0.339719
# 445921      0.268936
# 130618      0.468716
# 117660      0.267760
# 116181      0.206994
# 189500      0.346363
# 290539      0.196217
# 15240       0.354442
# 90645       0.196728
# 443673      0.299608
# 455725      0.494505
# 199925      0.427157
# 397194      0.473387

# %%
def compute_threshold(label_true, predict, thresh_precision: float = 0.99) -> None:
    precision_, recall_, thresholds_ = precision_recall_curve(label_true, predict)
    print('/***********/')
    if len(np.where(precision_ > thresh_precision)[0]) > 0:
        idx = np.where(precision_ > thresh_precision)[0][0]
        curr_predict = list()
        for pred in predict:
            if pred > thresholds_[idx]:
                curr_predict.append(1)
            else:
                curr_predict.append(0)

        f1_curr = f1_score(label_true, curr_predict, average='macro')
        print(f'F1-macro: {f1_curr}\nPrecision: {precision_[idx]}\nRecall: {recall_[idx]}\nThresholds: {thresholds_[idx]}')
    else: 
        print('Not Found!')

# %%
precision_value = np.linspace(0.5, 0.99, 50)
precision_value
# Out:
# array([0.5 , 0.51, 0.52, 0.53, 0.54, 0.55, 0.56, 0.57, 0.58, 0.59, 0.6 ,
#        0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.7 , 0.71,
#        0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.8 , 0.81, 0.82,
#        0.83, 0.84, 0.85, 0.86, 0.87, 0.88, 0.89, 0.9 , 0.91, 0.92, 0.93,
#        0.94, 0.95, 0.96, 0.97, 0.98, 0.99])

# %%
for prec in precision_value:
    compute_threshold(val_dataset.samples['is_duplicate'], val_dataset.samples['cosine_score'], prec)
# Out:
# /***********/
# F1-macro: 0.5772439559140294
# Precision: 0.5151515151515151
# Recall: 0.09289617486338798
# Thresholds: 0.8702144622802734
# /***********/
# F1-macro: 0.5772439559140294
# Precision: 0.5151515151515151
# Recall: 0.09289617486338798
# Thresholds: 0.8702144622802734
# /***********/
# F1-macro: 0.5776235647961
# Precision: 0.53125
# Recall: 0.09289617486338798
# Thresholds: 0.8709054589271545
# /***********/
# F1-macro: 0.5776235647961
# Precision: 0.53125
# Recall: 0.09289617486338798
# Thresholds: 0.8709054589271545
# /***********/
# F1-macro: 0.5780066426114232
# Precision: 0.5483870967741935
# Recall: 0.09289617486338798
# Thresholds: 0.8712215423583984
# /***********/
# F1-macro: 0.5736560838303751
# Precision: 0.5666666666666667
# Recall: 0.09289617486338798
# Thresholds: 0.8727751970291138
# /***********/
# F1-macro: 0.5736560838303751
# Precision: 0.5666666666666667
# Recall: 0.09289617486338798
# Thresholds: 0.8727751970291138
# /***********/
# F1-macro: 0.5696130303973441
# Precision: 0.5714285714285714
# Recall: 0.08743169398907104
# Thresholds: 0.8736584186553955
# /***********/
# F1-macro: 0.566165941553304
# Precision: 0.5833333333333334
# Recall: 0.07650273224043716
# Thresholds: 0.8807160258293152
# /***********/
# F1-macro: 0.5665075809642257
# Precision: 0.6086956521739131
# Recall: 0.07650273224043716
# Thresholds: 0.8824421167373657
# /***********/
# F1-macro: 0.5665075809642257
# Precision: 0.6086956521739131
# Recall: 0.07650273224043716
# Thresholds: 0.8824421167373657
# /***********/
# F1-macro: 0.5668524701421171
# Precision: 0.6363636363636364
# Recall: 0.07650273224043716
# Thresholds: 0.8844023942947388
# /***********/
# F1-macro: 0.5668524701421171
# Precision: 0.6363636363636364
# Recall: 0.07650273224043716
# Thresholds: 0.8844023942947388
# /***********/
# F1-macro: 0.5668524701421171
# Precision: 0.6363636363636364
# Recall: 0.07650273224043716
# Thresholds: 0.8844023942947388
# /***********/
# F1-macro: 0.5672006571191501
# Precision: 0.6666666666666666
# Recall: 0.07650273224043716
# Thresholds: 0.8859649896621704
# /***********/
# F1-macro: 0.5672006571191501
# Precision: 0.6666666666666666
# Recall: 0.07650273224043716
# Thresholds: 0.8859649896621704
# /***********/
# F1-macro: 0.5672006571191501
# Precision: 0.6666666666666666
# Recall: 0.07650273224043716
# Thresholds: 0.8859649896621704
# /***********/
# F1-macro: 0.5675521908786281
# Precision: 0.7
# Recall: 0.07650273224043716
# Thresholds: 0.8896095752716064
# /***********/
# F1-macro: 0.5675521908786281
# Precision: 0.7
# Recall: 0.07650273224043716
# Thresholds: 0.8896095752716064
# /***********/
# F1-macro: 0.5675521908786281
# Precision: 0.7
# Recall: 0.07650273224043716
# Thresholds: 0.8896095752716064
# /***********/
# F1-macro: 0.562911827984179
# Precision: 0.7368421052631579
# Recall: 0.07650273224043716
# Thresholds: 0.8933193683624268
# /***********/
# F1-macro: 0.562911827984179
# Precision: 0.7368421052631579
# Recall: 0.07650273224043716
# Thresholds: 0.8933193683624268
# /***********/
# F1-macro: 0.562911827984179
# Precision: 0.7368421052631579
# Recall: 0.07650273224043716
# Thresholds: 0.8933193683624268
# /***********/
# F1-macro: 0.562911827984179
# Precision: 0.7368421052631579
# Recall: 0.07650273224043716
# Thresholds: 0.8933193683624268
# /***********/
# F1-macro: 0.5585367897916867
# Precision: 0.7647058823529411
# Recall: 0.07103825136612021
# Thresholds: 0.8982406854629517
# /***********/
# F1-macro: 0.5585367897916867
# Precision: 0.7647058823529411
# Recall: 0.07103825136612021
# Thresholds: 0.8982406854629517
# /***********/
# F1-macro: 0.5585367897916867
# Precision: 0.7647058823529411
# Recall: 0.07103825136612021
# Thresholds: 0.8982406854629517
# /***********/
# F1-macro: 0.5540729168852747
# Precision: 0.8
# Recall: 0.06557377049180328
# Thresholds: 0.9062479138374329
# /***********/
# F1-macro: 0.5540729168852747
# Precision: 0.8
# Recall: 0.06557377049180328
# Thresholds: 0.9062479138374329
# /***********/
# F1-macro: 0.5540729168852747
# Precision: 0.8
# Recall: 0.06557377049180328
# Thresholds: 0.9062479138374329
# /***********/
# F1-macro: 0.5446171296846843
# Precision: 0.8333333333333334
# Recall: 0.0546448087431694
# Thresholds: 0.9244780540466309
# /***********/
# F1-macro: 0.5446171296846843
# Precision: 0.8333333333333334
# Recall: 0.0546448087431694
# Thresholds: 0.9244780540466309
# /***********/
# F1-macro: 0.5446171296846843
# Precision: 0.8333333333333334
# Recall: 0.0546448087431694
# Thresholds: 0.9244780540466309
# /***********/
# F1-macro: 0.5446171296846843
# Precision: 0.8333333333333334
# Recall: 0.0546448087431694
# Thresholds: 0.9244780540466309
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552
# /***********/
# F1-macro: 0.5089861036712661
# Precision: 1.0
# Recall: 0.01639344262295082
# Thresholds: 0.9999999403953552

# %%
val_dataset.samples['cosine_score']
# Out:
# (array([0.00934818, 0.00929757, 0.00929805, ..., 1.        , 1.        ,
#         1.        ]),
#  array([1.        , 0.99453552, 0.99453552, ..., 0.01639344, 0.01092896,
#         0.        ]),
#  array([0.18663622, 0.18664634, 0.18665883, ..., 0.97762394, 0.99999994,
#         1.        ]))

# %%
thresh = [
    0.5, 0.523047, 0.55, 0.57, 0.6, 0.62, 0.642733, 0.67, 0.7, 0.72, 0.74, 0.76, 0.78, 0.8, 0.82, 0.84, 0.86, 0.88, 0.9
]

for thr in thresh:
    curr_predict = list()
    for score in val_dataset.samples['cosine_score']:
        if score > thr:
            curr_predict.append(1)
        else:
            curr_predict.append(0)
            
    f1_curr = f1_score(val_dataset.samples['is_duplicate'], curr_predict, average='macro')
    print('/************/')
    print(f'Threshold for cosine similarity: {thr}')
    print(f'f1_macro: {f1_curr}')
    print('Classification report:')
    print(classification_report(val_dataset.samples['is_duplicate'], curr_predict))
# Out:
# /************/
# Threshold for cosine similarity: 0.5
# f1_macro: 0.4772386731468385
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     24708
#            1       0.03      0.76      0.06       183
#
#     accuracy                           0.82     24891
#    macro avg       0.51      0.79      0.48     24891
# weighted avg       0.99      0.82      0.89     24891
#
# /************/
# Threshold for cosine similarity: 0.523047
# f1_macro: 0.4923414540175656
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92     24708
#            1       0.04      0.75      0.07       183
#
#     accuracy                           0.85     24891
#    macro avg       0.52      0.80      0.49     24891
# weighted avg       0.99      0.85      0.91     24891
#
# /************/
# Threshold for cosine similarity: 0.55
# f1_macro: 0.5086590048084573
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94     24708
#            1       0.04      0.71      0.08       183
#
#     accuracy                           0.88     24891
#    macro avg       0.52      0.80      0.51     24891
# weighted avg       0.99      0.88      0.93     24891
#
# /************/
# Threshold for cosine similarity: 0.57
# f1_macro: 0.5202819993723945
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95     24708
#            1       0.05      0.68      0.09       183
#
#     accuracy                           0.90     24891
#    macro avg       0.52      0.79      0.52     24891
# weighted avg       0.99      0.90      0.94     24891
#
# /************/
# Threshold for cosine similarity: 0.6
# f1_macro: 0.5366992414560746
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96     24708
#            1       0.06      0.62      0.11       183
#
#     accuracy                           0.93     24891
#    macro avg       0.53      0.77      0.54     24891
# weighted avg       0.99      0.93      0.96     24891
#
# /************/
# Threshold for cosine similarity: 0.62
# f1_macro: 0.5445702010414406
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97     24708
#            1       0.07      0.55      0.12       183
#
#     accuracy                           0.94     24891
#    macro avg       0.53      0.75      0.54     24891
# weighted avg       0.99      0.94      0.96     24891
#
# /************/
# Threshold for cosine similarity: 0.642733
# f1_macro: 0.5560496370174537
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     24708
#            1       0.08      0.50      0.14       183
#
#     accuracy                           0.95     24891
#    macro avg       0.54      0.73      0.56     24891
# weighted avg       0.99      0.95      0.97     24891
#
# /************/
# Threshold for cosine similarity: 0.67
# f1_macro: 0.5667644205186703
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     24708
#            1       0.09      0.43      0.15       183
#
#     accuracy                           0.96     24891
#    macro avg       0.54      0.70      0.57     24891
# weighted avg       0.99      0.96      0.98     24891
#
# /************/
# Threshold for cosine similarity: 0.7
# f1_macro: 0.5784809223865287
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     24708
#            1       0.11      0.36      0.17       183
#
#     accuracy                           0.97     24891
#    macro avg       0.55      0.67      0.58     24891
# weighted avg       0.99      0.97      0.98     24891
#
# /************/
# Threshold for cosine similarity: 0.72
# f1_macro: 0.5812730537296995
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     24708
#            1       0.12      0.30      0.17       183
#
#     accuracy                           0.98     24891
#    macro avg       0.56      0.64      0.58     24891
# weighted avg       0.99      0.98      0.98     24891
#
# /************/
# Threshold for cosine similarity: 0.74
# f1_macro: 0.5877448184748904
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     24708
#            1       0.14      0.26      0.18       183
#
#     accuracy                           0.98     24891
#    macro avg       0.57      0.62      0.59     24891
# weighted avg       0.99      0.98      0.99     24891
#
# /************/
# Threshold for cosine similarity: 0.76
# f1_macro: 0.5965148322256443
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     24708
#            1       0.17      0.23      0.20       183
#
#     accuracy                           0.99     24891
#    macro avg       0.58      0.61      0.60     24891
# weighted avg       0.99      0.99      0.99     24891
#
# /************/
# Threshold for cosine similarity: 0.78
# f1_macro: 0.6048614759944639
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     24708
#            1       0.22      0.21      0.22       183
#
#     accuracy                           0.99     24891
#    macro avg       0.61      0.60      0.60     24891
# weighted avg       0.99      0.99      0.99     24891
#
# /************/
# Threshold for cosine similarity: 0.8
# f1_macro: 0.604738589341283
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     24708
#            1       0.25      0.19      0.21       183
#
#     accuracy                           0.99     24891
#    macro avg       0.62      0.59      0.60     24891
# weighted avg       0.99      0.99      0.99     24891
#
# /************/
# Threshold for cosine similarity: 0.82
# f1_macro: 0.6026120921263962
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     24708
#            1       0.29      0.16      0.21       183
#
#     accuracy                           0.99     24891
#    macro avg       0.64      0.58      0.60     24891
# weighted avg       0.99      0.99      0.99     24891
#
# /************/
# Threshold for cosine similarity: 0.84
# f1_macro: 0.5983928445901588
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     24708
#            1       0.38      0.14      0.20       183
#
#     accuracy                           0.99     24891
#    macro avg       0.69      0.57      0.60     24891
# weighted avg       0.99      0.99      0.99     24891
#
# /************/
# Threshold for cosine similarity: 0.86
# f1_macro: 0.5814162327965452
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     24708
#            1       0.42      0.10      0.17       183
#
#     accuracy                           0.99     24891
#    macro avg       0.71      0.55      0.58     24891
# weighted avg       0.99      0.99      0.99     24891
#
# /************/
# Threshold for cosine similarity: 0.88
# f1_macro: 0.5658275048053382
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     24708
#            1       0.58      0.08      0.14       183
#
#     accuracy                           0.99     24891
#    macro avg       0.79      0.54      0.57     24891
# weighted avg       0.99      0.99      0.99     24891
#
# /************/
# Threshold for cosine similarity: 0.9
# f1_macro: 0.5585367897916867
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     24708
#            1       0.75      0.07      0.12       183
#
#     accuracy                           0.99     24891
#    macro avg       0.87      0.53      0.56     24891
# weighted avg       0.99      0.99      0.99     24891

# %% [markdown]
# ### Create embeddings for database

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
import numpy as np

DEVICE = 'cuda:2'

# %%
model = SentenceTransformer('../weights/sbert', device=DEVICE)
model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 60, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# )

# %%
df = pd.read_csv('../data/companies_bd.csv')
embeddings = model.encode(df['company_preprocess'].tolist(), convert_to_tensor=True, device=DEVICE)
embeddings = embeddings.cpu().detach().numpy()

print(embeddings.shape)
embeddings
# Out:
# (18022, 384)
# array([[-0.05934985,  0.06893621,  0.00014626, ..., -0.08591195,
#          0.01250552,  0.00432631],
#        [-0.02718785,  0.00361338, -0.00428651, ..., -0.11769559,
#          0.05474156,  0.03105667],
#        [-0.02900415,  0.0220439 , -0.03527989, ..., -0.01598695,
#          0.04047029,  0.03884263],
#        ...,
#        [-0.03676479,  0.02781066, -0.07521491, ..., -0.11394496,
#         -0.02894348,  0.01878491],
#        [-0.06939244, -0.01332702,  0.03856129, ..., -0.03526384,
#         -0.02008867, -0.00478375],
#        [-0.08304074, -0.01968467, -0.04271364, ..., -0.00400955,
#          0.0590724 , -0.09089352]], dtype=float32)

# %%
with open('../data/embeddings_bd.npy', 'wb') as f:
    np.save(f, embeddings)

# %%
embeddings_load_test = np.load('../data/embeddings_bd.npy')
